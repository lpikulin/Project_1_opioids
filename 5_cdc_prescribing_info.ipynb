# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import csv
import json
import urllib
import seaborn as sns
from scipy.stats import linregress
from sklearn import datasets
import matplotlib.ticker as mtick

# %%
rx_df = pd.read_csv("data/rx_yearly.csv")
rx_df
# Out:
#    Year  Total Number of Prescriptions  Prescribing Rate Per 100 People
# 0  2009                      243738090                             79.5
# 1  2010                      251088904                             81.2
# 2  2011                      252167963                             80.9
# 3  2012                      255207954                             81.3
# 4  2013                      247090443                             78.1
# 5  2014                      240993021                             75.6
# 6  2015                      226819924                             70.6
# 7  2016                      214881622                             65.5
# 8  2017                      191909384                             59.0
# 9  2018                      168158611                             51.4

# %%
# bar chart rx per year 

years = (2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018)
rx_df['rx_mil']=rx_df['Total Number of Prescriptions']/100000000

plt.bar(x = rx_df['Year'], height = rx_df['rx_mil'], color= ['blue','orange','cyan','m','darkorchid','lime', 'red', 'lightskyblue', 'yellow', 'fuchsia'],
alpha = 1.0)
plt.xticks(years, rotation = 45, fontsize = 10, fontweight = 'bold')
plt.ylabel('Rxs dispensed (100 millions)',fontweight = 'bold')               
plt.yticks(np.arange(0, 3, .25), fontsize = 13)
plt.title('Opioid Rxs dispensed yearly', fontsize = 16, fontweight = 'bold')  
plt.ylim([0, 3])
plt.grid(which='major', linestyle='-', linewidth='0.5', color='silver')

# customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# plt.savefig('visualizations/Prescriptions Dispensed Yearly.png')
plt.show()

# %%
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.
    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """
    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off
    for rect in rects:
        height = rect.get_height()
        ax1.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom', rotation = 45)
fig1, ax1 = plt.subplots(figsize = (9,6))
# bar chart rx per year per 100 persons
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
rx_df['rx_mil']=rx_df['Total Number of Prescriptions']/100000000

graph = ax1.bar(x = rx_df['Year'], height = rx_df['rx_mil'], color= ['blue','orange','cyan','m','darkorchid',
                'lime', 'red', 'lightskyblue', 'yellow', 'fuchsia'], alpha = 1.0)
plt.xticks(years, rotation = 45, fontsize = 10, fontweight = 'bold')
plt.ylabel('Rxs dispensed (100 millions)', fontweight = 'bold')
plt.yticks(np.arange(0, 3, .25), fontsize = 13, fontweight = 'bold')
plt.title('Opioid Rxs dispensed yearly', fontsize = 16, fontweight = 'bold')
plt.ylim([0, 3])

autolabel(graph)
plt.savefig('visualizations/Prescriptions Dispensed Yearly per 100 Persons.png')
plt.show()

# %%
# bar chart rx per year per 100 persons 

def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.
    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """
    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off
    for rect in rects:
        height = rect.get_height()
        ax1.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom', rotation = 45)
fig1, ax1 = plt.subplots(figsize = (9,6))
# bar chart rx per year per 100 persons
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y_values = [79.5, 81.2, 80.9, 81.3, 78.1, 75.6,70.6, 65.5, 59.0, 51.4]

graph = ax1.bar(x = rx_df['Year'], height = rx_df['Prescribing Rate Per 100 People'],
        color= ['blue','orange','cyan','m','darkorchid','lime', 'red', 'lightskyblue', 'yellow', 'fuchsia'], alpha = 1.0)
plt.xticks(years, rotation = 45, fontsize = 10, fontweight = 'bold')
plt.ylabel('Prescriptions dispensed per 100 persons', fontweight = 'bold')
plt.yticks(np.arange(0, 100, 10), fontsize = 13, fontweight = 'bold')
plt.title('Opioid prescriptions dispensed yearly per 100 persons', fontsize = 16, fontweight = 'bold')
plt.ylim([0, 100])

autolabel(graph)
plt.savefig('visualizations/Prescriptions Dispensed Yearly per 100 Persons.png')
plt.show()

# %%
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.
    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """
    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off
    for rect in rects:
        height = rect.get_height()
        ax1.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(height), ha=ha[xpos], va='bottom', rotation = 45)
fig1, ax1 = plt.subplots(figsize = (9,6))
# bar chart rx per year per 100 persons
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
y_values = [79.5, 81.2, 80.9, 81.3, 78.1, 75.6,70.6, 65.5, 59.0, 51.4]

graph = ax1.bar(x = rx_df['Year'], height = rx_df['Prescribing Rate Per 100 People'],
        color= ['blue','orange','cyan','m','darkorchid','lime', 'red', 'lightskyblue', 'yellow', 'fuchsia'], alpha = 1.0)
plt.xticks(years, rotation = 45, fontsize = 10)
plt.ylabel('Prescriptions dispensed per 100 persons')
plt.yticks(np.arange(0, 100, 10), fontsize = 13)
plt.title('Opioid prescriptions dispensed yearly per 100 persons', fontsize = 16, fontweight = 'bold')
plt.ylim([0, 100])
plt.grid(which='major', linestyle='-', linewidth='0.5', color='silver')
# customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
autolabel(graph)
# plt.savefig('visualizations/Prescriptions Dispensed Yearly per 100 Persons.png')
plt.show()
